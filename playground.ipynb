# %%
import networkx as nx
import osmnx as ox
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors

# %matplotlib inline

ox.config(use_cache=True, log_console=True)

# %%
# plot drive network of Wilmersdorf, Berlin
G = ox.graph_from_place('Wilmersdorf, Berlin, Germany', network_type='drive')
fig, ax = ox.plot_graph(G)

# %%
# plot walk network of Berlin
G = ox.graph_from_place('Wilmersdorf, Berlin, Germany', network_type='walk')
fig, ax = ox.plot_graph(G)

# %%
# plot bike network of Berlin
G = ox.graph_from_place('Wilmersdorf, Berlin, Germany', network_type='bike')
fig, ax = ox.plot_graph(G)
